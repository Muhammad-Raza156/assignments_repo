# %%
<h1 align="center">Practical Learning Data Science and Machine Learning - Assignment 04</h1>

Write your answers based on your understanding. After completing this assignment, submit this notebook on Google Classroom. Mention your username in the following format: **Assignment # 04 (Your Name)**.


## Question 01:
Look at the following statement: 

numbers = [10, 20, 30, 40, 50]

- How many elements does the list have?
- What is the index of the first element in the list?
- What is the index of the last element in the list?
# Here write your answer
number= [10,20,30,40,50]

print(len(number))
print(number.index(10))
print(number.index(50))


## Question 02:
Look at the following statement:    

numbers = [1, 2, 3]

- What value is stored in numbers[2]?
- What value is stored in numbers[0]?
- What value is stored in numbers[-1]?
# Here write your answer
numbers=[1,2,3]

print(numbers[2])
print(numbers[0])
print(numbers[-1])


## Question 03:

Assume the lists `numbers1` has 100 elements and `numbers2` is an empty list. Write
code that copies the values in numbers1 to numbers2.
# Here write your answer

numbers1 = list(range(1,101))
numbers2 = []
numbers2= numbers1[:]
print(f"Number of elements in both lists are {len(numbers1)} and {len(numbers2)}")
## Question 04:

### Number Analysis Program

Design a program that asks the user to enter a `series of 5 numbers`. The program should
store the numbers in a list and then display the following data:

- The lowest number in the list
- The highest number in the list
- The total of the numbers in the list
- The average of the numbers in the list
# Here write your answer
user_numbers=[]

user_numbers.append(int(input("Enter 1st number: ")))
user_numbers.append(int(input("Enter 2nd number: ")))
user_numbers.append(int(input("Enter 3rd number: ")))
user_numbers.append(int(input("Enter 4th number: ")))
user_numbers.append(int(input("Enter 5th number: ")))
user_numbers
print(f"lowest number {min(user_numbers)}")
print(f"highest number {max(user_numbers)}")
print(f"Total of the numbers in the list {sum(user_numbers)}")
print(f"average of numbers in the list {sum(user_numbers)/len(user_numbers)}")
## Question 05:
How do you perform the following tasks with lists in Python

- Test that two lists contain the same elements in the same order.
- Copy one list to another. 
- Fill a list with zeroes, overwriting all elements in it.
- Remove all elements from a list.

# part no 01
list1=[1,2,3,4,5]
list2=[1,2,3,4,5]

print(list1 == list2)
# part no 02
list3=[]
list3=list1[:]
print(list1)
print(list3)
# part no 03
list1=[1,2,3,4,5]
list1[:]=[0]*len(list1)
list1
# part no 04
list3.clear()
list3

## Question 06:

Write a program that initializes a list with ten random integers and then prints four lines of output, each containing:

- Every element at an even index.
- Every even element.
- All elements in reverse order.
- Only the first and last elements.
# Here write your answer
import random
random_list= random.sample(range(1,101), 10)
#help(random.sample)
random_list
for i in range(len(random_list)):
    if i%2==0:
        print(f"Element at index{i} is {random_list[i]}")
for i in range(len(random_list)):
    if random_list[i]%2==0:
        print(f"Element at index{i} is {random_list[i]}")
print(sorted(random_list, reverse=True))
print(random_list[0], random_list[-1])
random_list
## Question 07:
Write a function `removeMin` that removes the minimum value from a list without using the `min` function or `remove` method. 
# 1st Method
# Here write your answer
def removeMin(list1):
    return sorted(list1)
reverse_list=  removeMin(random_list)
reverse_list
del reverse_list[0]
# 2nd Method using for loop and if statement
minimum= random_list[0]
print(minimum)
for i in range(len(random_list)):
    if random_list[i] < minimum:
        min_indx=i
        minimum=random_list[i]
print(minimum)
print(min_indx)
del random_list[min_indx]
random_list
## Question 08:

One acre of land is equivalent to `43,560` square feet. Write a program that asks the user 
to enter the total square feet in a tract of land, and then calculates and display the number of acres in the tract.


$$ \mathbf{Number of Acres = \frac{Total\ Square\ Feet}{43,560}}$$

# Here write your answer
measurement= int(input("Enter the measurement of land in square feet: "))
no_of_acres= measurement/43560
print(f"Number of acres in {measurement} square feet are {no_of_acres}")
## Question 09:


There are three seating categories at a stadium. For a softball game, `Class A` seats cost 
$ \$15$, `Class  B`  seats  cost $ \$12 $, and `Class C` seats cost $ \$9$. Write a program that asks how many  tickets for each class of seats were sold, and then displays the amount of income 
generated from ticket sales.
.

# Here write your answer
sold_A= int(input("Enter number of tickets sold for A class:  "))
sold_B= int(input("Enter number of tickets sold for B class:  "))
sold_C= int(input("Enter number of tickets sold for C class:  "))
income_from_tickets= (sold_A*15)+(sold_B*12)+(sold_C*9)
print(f"Income generated from sales of tickets ${income_from_tickets}")
## Question 10:
Write a program in which create a list of 10 random integers and find the product of all elements of a list.
**First Method:**
Using Functions and Loops
random_numbers= [1,3,6,9,10,11,23,25, 30, 35]
def product(list1):
    product_list=1
    for i in list1:
        product_list=product_list*i
    return product_list
prod=product(random_numbers)
print(f"Product of all numbers of list is {prod}")
from functools import reduce
prod2=reduce(lambda x,y : x*y, random_numbers)
prod2
**Second Method :**

- Firstly, we will get a List of 10 random integers using `random` module
- Then we use functions and loops to find product of all the numbers of the list.
import random
rand_list= random.sample(range(1,50),10)
rand_list
prod3=1
for i in rand_list:
    prod3=prod3*i
print(f"Product of all numbers in list {rand_list} is: {prod3} ")
prod4= reduce(lambda x,y : x*y, rand_list)
print(f"Product of all numbers in list {rand_list} using reduce function  is: {prod4} ")
## Question 11:
Given the set definitions below, answer the following questions:    

set1 = { 1, 2, 3, 4, 5 }   
set2 = { 2, 4, 6, 8 }    
set3 = { 1, 5, 9, 13, 17 }


- Is set1 a subset of set2?
- Is the intersection of set1 and set3 empty?
- What is the result of performing set union on set1 and set2?
- What is the result of performing set intersection on set2 and set3?
- What is the result of performing set intersection on all three sets?
- What is the result of performing the set difference on set1 and set2 (set1 – set2)?
- What is the result of the instruction set1.discard(5)? 
- What is the result of the instruction set2.discard(5)? 
help(set)
# Here write your answer
set1 = {1,2,3,4,5}
set2 = {2,4,6,8}
set3 = {1,5,9,13,17}
# part no 01
print("Checking whether set1 is subset of set2\n", set1.issubset(set2))
# part no 02
print("Intersection of set1 and set3\n", set1.intersection(set3))
# part no 03
print("Union of set1 and set2 \n", set1.union(set2))
# part no 04:
print("Intersection of set2 and set3\n", set2.intersection(set3))
# part no 05
print("Intersection of all three sets set1, set2 and set3\n", set1.intersection(set2,set3))
result= set1 & set2 & set3
print(f"Intersection of set1,set2 and set3 using other method\n {result}")
# part no 06
print("Difference between set1 and set2\n" ,set1.difference(set2))
# part no 07
set1.discard(5)
print(f"After discarding 5 from set1 {set1}")
# part no 08
result2=set2.discard(5)
print(result2)
print(set2)


## Question 12:

Given three sets, `set1`, `set2`, and `set3`, write Python statement(s) to perform the following actions: 

- Create a new set of all elements that are in set1 or set2, but not both.
- Create a new set of all elements that are in only one of the three sets set1, set2, and set3.
- Create a new set of all elements that are in exactly two of the sets set1, set2, and set3.
- Create a new set of all integer elements in the range 1 through 25 that are not in set1.
- Create a new set of all integer elements in the range 1 through 25 that are not in any of the three sets set1, set2, or set3.
- Create a new set of all integer elements in the range 1 through 25 that are not in all three sets set1, set2, and set3.
Here you can also manully add elements in the sets by using loops.     
But in this case, use `random` module to generate all sets

# Here write your answer
#     part no 01
set4=set1.symmetric_difference(set2)
print(f"set of elements only in set1 and set2 exclusively not both\n {set4} ")
#     part no 02
union_of_all_sets= set1 | set2 | set3
intersection_of_all_sets= set1 & set2 & set3

intersect12= set1.intersection(set2)
intersect23= set2.intersection(set3)
intersect13= set1.intersection(set3)

union_of_intersections= intersect12 | intersect23 | intersect13

result3 = union_of_all_sets - (union_of_all_sets & union_of_intersections) - intersection_of_all_sets

print(f"set of all elements that are in only one of the three sets set1, set2, and set3\n {result3}")

#     part no 03

result4= union_of_intersections-(union_of_all_sets-union_of_intersections)

print(f"set of all elements that are in exactly two of the sets set1, set2, and set3\n {result4}")
#     part no 04
all_integers= set(range(1,26))

result5= all_integers-set1
print(f"set of all integer elements in the range 1 through 25 that are not in set1\n {result5}")

#     part no 05

result6= all_integers-union_of_all_sets
print(f"set of all integer elements in the range 1 through 25 that are not in any of the three sets\n {result6}")


#     part no 06
result7= all_integers-intersection_of_all_sets
print(f"set of all integer elements in the range 1 through 25 that are not in all three sets\n {result7}")

## Question 13:

Write a program that prompts the user to enter `two strings` and then prints the following:

- The characters that are common to both strings.
- The characters that appear in one string but not the other.
- The characters that do not appear in either string.

You can achieve this by utilizing the `set` function to convert a string into a set of characters.



**Test Case:**

Imagine two strings:

- String A: "hello"
- String B: "world"

The expected outputs would be:

- Common characters: "o"
- Unique characters in String A: "hel"
- Unique characters in String B: "wrld"
str1=str(input("Enter a text: "))
str2=str(input("Enter a text: "))
print(str1)
print(str2)
**First Method:**

Using built-in set functions
# Here write your code
str1_set=set(str1)
str2_set=set(str2)
str1_set
print(f"Common characters {str1_set.intersection(str2_set)}")
print(f"Unique characters in {str1}: {str1_set}")
print(f"Unique characters in {str2}: {str2_set}")
**Second Method :**

Using Loops and if statement
# Here write your code
common_characters=[]

for char in str1:
    if char in str2:
        common_characters.append(char)
print(char)
unique_str1=[]
for char in str1:
    if char not in unique_str1:
        unique_str1.append(char)
print(f"Unique characters in String1 are:  {unique_str1}")
unique_str2=[]
for char in str2:
    if char not in unique_str2:
        unique_str2.append(char)
print(f"Unique characters in String2 are:  {unique_str2}")
## Question 14:


### Rainfall Statistics

Develop a program that allows the user to input the total rainfall for each of the 12 months into a list. The program should then compute and present the following information:

- Total rainfall for the entire year.
- Average monthly rainfall.
- Months with the highest and lowest amounts of rainfall.


**Test Case:**

Imagine the following monthly rainfall data (in inches):

- January: 2
- February: 3
- March: 4
- April: 2
- May: 1
- June: 5
- July: 6
- August: 4
- September: 3
- October: 2
- November: 1
- December: 2

**Expected Results:**
- Total annual rainfall: 35 inches
- Average monthly rainfall: 2.92 inches
- Highest rainfall month: July
- Lowest rainfall month: May
# Here write your answer
list_months=["January", "February","March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
rainfall_perMonth=[]

for i in list_months:
    rainfall_perMonth.append(int(input(f"Enter amount of rainfall for {i} : ")))
rainfall_perMonth
total_annual_rainfall= reduce(lambda x,y : x+y,rainfall_perMonth)
avrg= total_annual_rainfall/len(rainfall_perMonth)
highest_rainfall = max(rainfall_perMonth)
lowest_rainfall = min(rainfall_perMonth)

rainfall_dict = dict(zip(list_months, rainfall_perMonth))
print(rainfall_dict)
def get_key_from_value(dictionary, value):
    month=""
    for key, val in dictionary.items():
        if val == value:
            month=key
            break
    return month
highest_rainfall_month=get_key_from_value(rainfall_dict, highest_rainfall)
lowest_rainfall_month=get_key_from_value(rainfall_dict, lowest_rainfall)
print(f"Total Annual rainfall {total_annual_rainfall} inches")
print(f"Average monthly rainfall:  {round(avrg)} inches")
print(f"Highest rainfall month : {highest_rainfall_month}")
print(f"L0west rainfall month : {lowest_rainfall_month}")
## Question 15:

Given the tuple `T1 = (1, 23, 4, 5, "A", ["C", "D"], (23, 45), 45)`:

- a. Determine the total number of elements in the given tuple.
- b. Find the index of a specific given element.
- c. Find the occurrence count of a specific given element.
- d. Print the characters "CC" using elements from the tuple.
- e. Display the first 5 elements of the tuple.
- f. Display the last 5 elements of the tuple.
- g. Demonstrate how to obtain the output `(45, ['C', 'D'], 5)` from the given tuple.
- h. Concatenate the elements of the tuples present at index 4 and 5.
- i. Apply the `max()` function on the given tuple and note the output.
help(tuple)
T1 = (1, 23, 4, 5, "A", ["C", "D"], (23, 45), 45)
# part no 01
print(f"Total number of elements in T1 are: {len(T1)}")
# part no 02
print(f"Element 4 is given at the index {T1.index(4)}")
# part no 03
print(f"5 occurs {T1.count(5)} times in T1")
# part no 04
print(T1[5][0] * 2)
# part no 05
print("First 5 elements of tuple T1: ", T1[:5])
# part no 06
print("Last 5 elements of tuple T1: ", T1[-5: ])
# part no 07
print((T1[7], T1[5], T1[3]))
# part no 08
print(T1[4]+str(T1[5]))
# part no 09
print(max(T1))
