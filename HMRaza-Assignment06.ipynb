# %%
<h1 align="center"> Practical Learning Data Science and Machine Learning - Assignment 06 </h1>
Write your answers based on your understanding. After completing this assignment, submit this notebook on Google Classroom. Mention your username in the following format: **Assignment # 06 (Your Name)**.


> **Note: Solve all the questions using user-defined functions and loops. Try to avoid using built-in functions.**


## Question No 01:

**You have been given a file named `File.txt`. Perform the following operations on the file data.**

- Read all the content of the file and store it in a `list`.
- Remove `spaces` from each element of the list and also remove a period (`.`) if a word/element contains one.
- Create a dictionary that stores the `key` as a word/element and the `value` as the occurrence/frequency of that word/element in the list.
- Sort the dictionary according to the words/elements with higher counts/occurrences.
- Display a dictionary containing words with values ranging between 15 and 20.
# Here is a syntax to read a file

with open('File.txt', 'r') as fl:
    data = fl.read()
    print(type(data))
    print(data)
# Here write your code
list_data= data.split(sep=' ')
#!dir
for i in range(len(list_data)):
    
    list_data[i]= list_data[i].strip()
    list_data[i]= list_data[i].replace('.',"")
occur_dict={}
for s in list_data:
    if s not in occur_dict.keys():
        occur_dict[s]=1
    else:
        occur_dict[s]=occur_dict[s]+1
#occur_dict
from collections import Counter
occur_dict1 = dict(Counter(list_data))
sorted_dict=sorted(occur_dict.items(), key= lambda s:s[1], reverse= True)
display_dict={word:occurrence for word, occurrence in sorted_dict if 15<= occurrence <=20}
display_dict
display_dict2={}
for idx, count in sorted_dict:
    if 15 <= count <= 20:
        display_dict2[idx]=count
display_dict2
## Question no 02:
Write a program in which take a sentence from user containing n words/strings. Remove all duplicates words/strings which are similar to each others.

#### Sample Output:
- Input : Python is great and Java is also great
- Output : is also Java Python and great
**First Method**
# Here write your answer
str1= str(input("Enter a string of words: "))
output= ' '.join(list(set(str1.split(sep=' '))))
print(output)
**Second Method:**

By using `for` loop and `list`.
str1_list=str1.split(sep=' ')
unique_list=[]

for s in str1_list:
    if s not in unique_list:
        unique_list.append(s)
str_unique= ' '.join(unique_list)
print(str_unique)
## Question no 03:

Print an inverted star pattern of the desired size.

Below is an inverted star pattern of size n=5. This pattern consists of 5 horizontal lines or rows of stars:
str1="""
   *****
    ****
     ***
      **
       *
       *
      **
     ***
    ****
   *****
"""
for i in range(len(list_str)):
    list_str[i]=list_str[i][::-1]
inverted='\n'.join(list_str)
print("Before inverting:\n", str1)
print("\n")
print("\n")
print("After inverting:\n",inverted)
#output=""
#i, j, k = 9, 0, 5
#while i >= -1:
 #   if i != 5:  # skip printing when i is 5
  #      if i > 5:
            #print('*' * k + ' ' * j)
   #         output+='*' * k + ' ' * j+"\n"
    #        j = j + 1
     #       k = k - 1
      #  else:
       #     #print('*' * k + ' ' * j)
        #    output+='*' * k + ' ' * j+"\n"
         #   j = j - 1
          #  k = k + 1
    #i = i - 1
#print(output)
## Question no 04:
Write a function called `half_and_half` that takes a list as input and modifies the list so that the elements of the second half are now in the first half.


### Sample : 
##### Case 1:
if the size of list is even and content of list is as follows :     
my_list = [10,20,30,40,50,60]     
The output: [40,50,60,10,20,30]    


##### Case 2:    
if the size of list is odd and content of list is as follows :     
my_list = [10,20,30,40,50,60,70]    
The output: [50,60,70,40,10,20,30]    
from math import ceil
# Here write your answer
my_list= [10,20,30,40,50,60]
my_list2=  [10,20,30,40,50,60,70]
my_list1=[]
def half_and_half(m):
    i=len(m)//2
    if len(m)%2==0:
        my_list1= m[i:]+m[:i]
    else:
        my_list1= m[ceil(i)+1:]+[m[ceil(i)]]+m[:ceil(i)]
    return my_list1
half_and_half(my_list2)
#ceil(7//2)
## Question no 05:

Write a function that takes a dictionary as an argument. If the dictionary contains duplicate values, return an empty dictionary; otherwise, return a new dictionary where the values become the keys, and the keys become the values.

### Sample : 
- Input : {'a': 10, 'b': 20, 'c': 20}
- Output : {}
# Here write your answer
dict1= {'a': 10, 'b': 20, 'c': 20}
def dup_dict(dict3):
    dup=[]
    for item in dict3.items():
        if item[1] not in dup:
            dup.append(item[1])
            dict3= dict(zip(list(dict3.values()),list(dict3.keys())))  
        else:
            dict3=dict()
    return dict3
dict2=dup_dict(dict1)
print(dict2)
## Question no 06:
### Test Average and Grade
Write a program that asks the user to enter five test scores. The program should display a letter grade for each score and the average test score. Write the following functions in the program:

- `calc_average` : This function should accept five test scores as arguments and returnthe average of the scores.
- `determine_grade` : This function should accept a test score as an argument andreturn a letter grade for the score, based on the following grading scale:
|Score   |       Letter Grade |
|--------|--------------------|
|90-100  |         A          |
| 80-89  |         B          |
| 70-79  |         C          |
| 60-69  |         D          |
|Below 60|         F          |
# Here write your asnwer
test_scores=[]
for i in range(1,6):
    test_scores.append(int(input(f"Enter the score for student {i}: ")))
test_scores
def calc_average(m):
    avg= sum(m)/len(m)
    return avg
average= calc_average(test_scores)
print(f"Average score is {average}")
def grades(m):
    for s in m:
        if 90 <= s <=100:
            print("Grade is A")
        elif 80 <= s <=89:
             print("Grade is B")
        elif 70 <= s <=79:
            print("Grade is C")
        elif 60 <= s <=69:
            print("Grade is D")
        else:
            print("Grade is F")
grades(test_scores)
## Question no 07:
#### Name and Email Addresses
Write a program that keeps names and email addresses in a dictionary as key-value pairs.
The program should display a menu that lets the user look up a person’s email address, add
a new name and email address, change an existing email address, and delete an existing
name and email address.
-               Menu 
- 1.Check Person's Email Address
- 2.Add new name and email
- 3.Change an existing email
- 4.Delete an existing email
# Here write your answer
dictmail={"Hafiz Muhammad Raza":"hafizrazam@gmail.com"}
dictmail
while(True):
    print("\n")
    opt= int(input(
                   """Check Person's Email Address press 1: 
                    Add new name and email press 2:  
                    Change an existing email press 3:  
                    Delete an existing email press 4:  
                    Exit the program enter any number greater than 4:\n """
                    ))
    print("\n")
    if opt == 1:
        Name= str(input("Enter the name of person: "))
        if Name not in dictmail.keys():
            print("Name not found in dictionary\n")
        else:
            print(f"Email address of {Name} is {dictmail[Name]}")
    elif opt == 2:
        new_name= str(input("Enter the name of the person: "))
        if new_name in dictmail.keys():
            print("Name already present in the dictionary\n")
        else:
            email= str(input("Enter an email address of the person: "))
            dictmail[new_name]= email
            print(f"After adding new record with key {new_name}:\n {dictmail}")
    elif opt == 3:
        key= str(input("Enter the name of the person for which you want to change email address: "))
        if key not in dictmail.keys():
            print("Record not available\n")
        else:
            email= str(input("Enter an email address to be updated: "))
            dictmail[key]= email
            print(f"After updating the email address for {key}:\n {dictmail}")
    elif opt == 4:
        key= str(input("Enter the name for which you want to delete record: "))
        if key not in dictmail.keys():
            print("Record not available\n")
        else:
            del dictmail[key]
            print(f"After deleting the record:\n {dictmail}")
    else:
        break
## Question no 08:


### Alphabetic Telephone Number Translator
Many companies use telephone numbers like 555-GET-FOOD so the number is easier for
their customers to remember. On a standard telephone, the alphabetic letters are mapped
to numbers in the following fashion:   
A, B, and C = 2     
D, E, and F = 3     
G, H, and I = 4    
J, K, and L = 5    
M, N, and O = 6    
P, Q, R, and S = 7    
T, U, and V = 8    
W, X, Y, and Z = 9    
Write a program that asks the user to enter a 10-character telephone number in the format
XXX-XXX-XXXX. The application should display the telephone number with any alphabetic characters that appeared in the original translated to their numeric equivalent.
### Sample: 
- Input: 555-GET-FOOD 
- Output: 555-438-3663
str1=str(input("Enter a 10-character telephone number in the format XXX-XXX-XXXX"))
dict1={'A':2, 'B':2, 'C':2, 'D':3, 'E':3, 'F':3, 'G':4, 'H':4, 'I':4, 'J':5, 'K':5, 'L':5, 'M':6, 'N':6, 'O':6,
      'P':7, 'Q':7, 'R':7, 'S':7, 'T':8, 'U':8, 'V':8, 'W':9, 'X':9, 'Y':9, 'Z':9 }
# Here write your answer
def  numberic_equivalent(str1):
    
    str2=str1[:]
    for s in str2:
        if s in dict1.keys():
            str2=str2.replace(s,str(dict1[s]))
    return str2
print(f"Input: {str1}")
print(f"Output: {numberic_equivalent(str1)}")
## Question no 09:
### Color Mixer
The colors red, blue, and yellow are known as the primary colors because they cannot be
made by mixing other colors. When you mix two primary colors, you get a secondary color,
as shown here: 
- When you mix red and blue, you get purple.
- When you mix red and yellow, you get orange.
- When you mix blue and yellow, you get green.    
    
Design a program that prompts the user to enter the names of two primary colors to mix.
If the user enters anything other than `red`, `blue` or `yellow` the program should display an error message. Otherwise, the program should display the name of the secondary
color that results. 
# Here write your answer
#color1=str(input("Enter a primary color: ")).lower()
#color2=str(input("Enter 2nd primary color: ")).lower()
while(True):
    color1=str(input("Enter a primary color: ")).lower()
    color2=str(input("Enter 2nd primary color: ")).lower()
    
    primary_colors=['red', 'blue', 'yellow']
    if color1 in primary_colors:
        if color2 in primary_colors:
            if (color1== 'red' or color1== 'blue') and (color2 == 'blue' or color2 == 'red' ):
                print(f"Primary colors {color1} and {color2} secondary color is purple")
                break
            elif (color1 == 'red' or color1 == 'yellow') and (color2 == 'yellow' or color2 == 'red'):
                print(f"Primary colors {color1} and {color2} secondary color is orange")
                break
            elif (color1 == 'blue' or color1 == 'yellow') and (color2 == 'yellow' or color2 == 'blue'):
                print(f"Primary colros {color1} and {color2} secondary color is green")
                break
        else:
            print(f"{color2} is not primary color")
            break
    else:
        print(f"{color1} is not primary color")
        break   

#secondary_color(color1,color2)
## Question no 10:
Write a function which takes a list of n-integers from user and display third largest element of the list without using built-in functions and also without using slicing.
### Sample :
- Input: [4,5,65,7,7,8,8,55,49]
- Output: 49
# Here write your answer
my_list1=[4,5,65,7,7,8,8,55,49]
def third_largest(my_list):
    
    for i in range(len(my_list)):
        for j in range(i+1,len(my_list)):
            if my_list[j]>my_list[i]:
                my_list[i], my_list[j] = my_list[j], my_list[i]
                #maxi=my_list[j]
                #my_list[j]=my_list[i]
                #my_list[i]=maxi
    return my_list
list1= third_largest(my_list1)
print(list1)
print(f" third largest in the list is {list1[2]}")

## Question no 11:
#### Make a function that encrypts a given input with these steps:
Input: `"apple"`   
Step 1: Reverse the input: `"elppa"`  
Step 2: Replace all vowels using the following chart:    
`a => 0`    
`e => 1`  
`i => 2`  
`o => 2`  
`u => 3`  
`# "1lpp0"`  
Step 3: Add `"aca"` to the end of the word: `"1lpp0aca"`  
Output: `"1lpp0aca"`  
**Examples:**   
`encrypt("banana") ➞ "0n0n0baca"`  
`encrypt("karaca") ➞ "0c0r0kaca"`  
`encrypt("burak") ➞ "k0r3baca"`  
`encrypt("alpaca") ➞ "0c0pl0aca"`  
# Here write your answer
dict1={'a':0, 'e':1, 'i':2, 'o':2 , 'u':3}

encr="aca"
def encrypt(str1):
    str2=str1[::-1]
    for s in str2:
        if s in list(dict1.keys()):
            str2=str2.replace(s,str(dict1[s]))
    encrypt_str=str2+encr
    return encrypt_str
encrypted=encrypt("apple")
print(encrypted)
## Question no 12:

### Financial Institution

Financial institution provides professional services to banks and claims charges from the customers based on the number of man-days provided. Internally, it has set a scheme to motivate and reward staff to meet and exceed targeted billable utilization and revenues by paying a bonus for each day claimed from customers in excess of a threshold target.

This quarterly scheme is calculated with a threshold target of 32 days per quarter, and the incentive payment for each billable day in excess of such threshold target is shown as follows:

| Days                | Bonus                        |
|---------------------|------------------------------|
| 0 to 32 days        | Zero                         |
| 33 to 40 days       | SGD$325 per billable day     |
| 41 to 48 days       | SGD$550 per billable day     |
| Greater than 48 days| SGD$600 per billable day     |
Please note that incentive payment is calculated progressively. As an example, if an employee reached total billable days of 45 in a quarter, his/her incentive payment is computed as follows:  
`32*0 + 8*325 + 5*550 = 5350`  
Write a function to read the billable days of an employee and return the bonus he/she has obtained in that quarter.

**Examples:**  
`bonus(15) ➞ 0`  
`bonus(37) ➞ 1625`  
`bonus(50) ➞ 8200`  
billable_days1=37
# Here write your answer
def calc_bonus(billable_days):
    
    if 32 < billable_days <= 40:
        bonus = 0+ 325*(billable_days-32)
    elif 41 <= billable_days <= 48:
        days1= billable_days-40
        bonus= 0+ 8*325+days1*550
    elif billable_days > 48:
        days2=billable_days-48
        bonus= 0+ 8*325+8*550+ days2*600
    else:
        bonus=0
    return bonus
bonus=calc_bonus(billable_days1)
print(f"Billable days {billable_days1} bonus is : {bonus} ")

## Question no 13:
#### Implement a Python program to generate all sentences where subject is in ["Pakistanis", "Indians"] and verb is in ["Play", "watch"] and the object is in ["Baseball","cricket"].
#### Hint: Subject,Verb and Object should be declared in the program as shown below.
subjects=["Pakistanis ","Indians"]    
verbs=["play","watch"]     
objects=["Baseball","Cricket"]    
#### Output should come as below:
- Pakistanis play Baseball.
- Pakistanis play Cricket.
- Pakistanis watch Baseball.
- Pakistanis watch Cricket.
- Indians play Baseball.
- Indians play Cricket.
- Indians watch Baseball.
- Indians watch Cricket.
# Here write your answer
subjects=["Pakistanis ","Indians"]
verbs=["play","watch"]
objects=["Baseball","Cricket"]
for s in subjects:
    for v in verbs:
        for o in objects:
            print(s+" "+v+" "+o+'.')
## Question no 14:
A non-governmental organization needs a program to calculate the amount of finan cial assistance for needy families. The formula is as follows:
- If the annual household income is between 30000 dollars and 40000 dollars and the household has at least three children, the amount is 1000 dollars per child.
- If the annual household income is between 20000 dollars and 30000 dollars and the household has at least two children, the amount is 1500 dollars per child.
- If the annual household income is less than 20000 dollars the amount is 2000 dollars per child.     
  
Implement a function for this computation. Write a program that asks for the 
household income and number of children for each applicant, printing the amount 
returned by your function. 
# Here write your answer
def financial_aid(inc,ch):
    fin_aid = 0
    if inc > 40000:
        print(f"{inc} is sufficient not eligible for financial support")
    elif 30000 <= inc <= 40000 and ch>=3:
        fin_aid= ch*1000
    elif 30000 <= inc <= 40000 and ch<3:
        print("Not eligible no. of children shall be more than 2")
    elif 20000 <= inc <= 30000 and ch>=2:
        fin_aid= ch*1500
    elif 20000 <= inc <= 30000 and ch<2:
        print("Not eligible no. of children shall be more than 1")
    elif inc<20000:
        fin_aid= ch*2000
    return fin_aid
while(True):
    
    exit=int(input("Enter 0 to exit or 1 to continue: "))
    if exit == 1:
        print("\n")
        inc= int(input("Enter house hold income: "))
        ch= int(input("Enter no. of children: "))
        fin_aid=financial_aid(inc,ch)
        print(f"Finacial support amount is  {fin_aid} dollars")
        print("\n")
    else:
        break



## Question no 15:
Write list functions that carry out the following tasks for a list of integers. For each 
function, provide a test program. 
- a. Swap the first and last elements in the list.
- b. Shift all elements by one to the right and move the last element into the first position. For example, 1 4 9 16 25 would be transformed into 25 1 4 9 16.
- c. Replace all even elements with 0.
- d. Replace each element except the first and last by the larger of its two neighbors.
- e. Remove the middle element if the list length is odd, or the middle two elements if the length is even.
- f. Move all even elements to the front, otherwise preserving the order of the elements. 
- g. Return the second-largest element in the list.
- h. Return true if the list is currently sorted in increasing order.
- i. Return true if the list contains two adjacent duplicate elements.
- j. Return true if the list contains duplicate elements (which need not be adjacent).
import copy
from math import ceil
# Here write your answer
list1=[1, 4, 9, 16, 25, 9]
def swap(list1):
    
    list2=copy.deepcopy(list1)
    list2[0],list2[-1]=list2[-1],list2[0]
    return list2
list2= swap(list1)
print(list2)
def rotate(list1):
    return [list1[-1]]+list1[:len(list1)-1]
rotated_list= rotate(list1)
print(rotated_list)
def even_zero(list1):
    list3= copy.deepcopy(list1)
    for i in range(len(list3)):
        if list3[i]%2==0:
            list3[i]=0
    return list3
list3= even_zero(list1)
print(list3)
def larger_neighbor(list1):
    list4= copy.deepcopy(list1)
    for i in range(1,len(list4)-1):
        list4[i]= max(list4[i-1], list4[i+1])
    return list4    
list4= larger_neighbor(list1)
print(list4)
def remove_middle(list1):
    list5= copy.deepcopy(list1)
    if len(list5)%2 != 0:
        del list5[ceil(len(list5)//2)]
    else:
        del list5[len(list5)//2], list5[len(list5)//2-1]
    return list5
list5= remove_middle(list1)
print(list5)
def even_odd_list(list1):
    list6= copy.deepcopy(list1)
    even_list=[i for i in list6 if i%2==0]
    odd_list= [i for i in list6 if i%2 != 0]
    return even_list+odd_list
list6=even_odd_list(list1)
print(list6)
def second_largest(list1):
    list7= copy.deepcopy(list1)
    for i in range(len(list7)):
        for j in range(i+1,len(list7)):
            if list7[j]>list7[i]:
                list7[i], list7[j] = list7[j], list7[i]
    return list7
list7= second_largest(list1)
print(f"Second largest {list7[1]}")
def is_sorted_ascend(list7):
    return all(list7[i] <= list7[i+1] for i in range(len(list7)-1))
ascend = is_sorted_ascend(list7)
print(ascend)
list8= sorted(list7)
ascend = is_sorted_ascend(list8)
print(ascend)
def duplicate(list1):
    dup= False
    unique=[]
    for s in list1:
        if s not in unique:
            unique.append(s)
        else:
            dup=True
    return dup
dup= duplicate(list1)
print(f"Duplicate: {dup}")
def adjacent_duplicate(list1):
    dup=False
    for i in range(len(list1)-1):
        if list1[i] == list1[i+1]:
            dup = True
        else:
            pass
    return dup
adj_dup=adjacent_duplicate(list1)
print(f"Adjacent Duplicate: {adj_dup}")
