# %%
<h1  align="center">Practical Learning Data Science and Machine Learning - Assignment 02 </h1>

Write your answers based on your understanding. After completing this assignment, submit this notebook on Google Classroom. Mention your username in the following format: **Assignment # 02 (Your Name)**.


## Question 01. Comments

What does a professional programmer usually do first to gain an understanding of a problem?
# Here write your answer
# First read and understand the problem statement
# If a confusion then ask questions from problem giver to clarify
# Divide a problem further into sub tasks to reduce the complexity
# Identify the input data and output to be generated , the data structures to be used, control flow, selection, 
#loops may be needed
## Question 02

If a math expression adds a float to an int, what will the data type of the result be?What is the difference between floating-point division and integer division?
# Here write your answer
# when a float is added to an integer then the result is of type float
# floating-point division gives the output result of float type while integer division gives output result an integer type whole number
a,b=10,20.3
total= a+b
print(total)
print(type(total))
a1=4//2
a2=5/2

print(type(a1))
print(type(a2))
### Question 03 

Write a program in which take two numbers from user by using built-in function and perform folllowing arithmetic operation

- Addition    
- Subtraction    
- Multiplication    
- Division   
# Here write your answer
n1 = int(input("Enter 1st number: "))
n2 = int(input("Enter 2nd number: "))
total=n1+n2
difference=n1-n2
product=n1*n2
division=n2//n1

print(total, difference, product, division, sep="\n")
## Question 04

Write a program to calculate area of triangle by using following formula , in this program takes all input from user by using built-in function.    

$$Area of a triangle = \sqrt{s \cdot (s-a) \cdot (s-b) \cdot (s-c)}$$

# Here write your answer
a = int(input("Enter length of 1st side of triangle: "))
b = int(input("Enter length of 2nd side of triangle: "))
c = int(input("Enter length of 3rd side of triangle: "))
s = int(input("Enter s of triangle: "))
import math
area_of_triangle= math.sqrt(s*(s-a)*(s-b)*(s-b))

print("Area of the triangle is: ", area_of_triangle)
## Question 05

Write a program in which take two numbers from user and swap them.
# Here write your answer

num1= int(input("Enter a number: "))
num2= int(input("Enter second number: "))
print("Befor swapping", num1, num2, sep="\n")

temp=num1
num1=num2
num2=temp

print("After swapping", num1, num2, sep="\n")
Question 06 

Write a program that prompts the user to input a Celsius temperature and outputs the equivalent temperature in Fahrenheit. The formula to convert the temperature is: $$\mathbf{F = \frac{9}{5}C + 32}$$ where F is the Fahrenheit temperature and C is the Celsius temperature. 
# Here write your answer
celsius= int(input("Enter temperature in celsius"))
F= (9/5)*celsius+32

print(f"Resulting Fahrenheit temperature for {celsius} celsius is {F}")
## Question 07 

Write a program that accepts seconds from user as integer. Your program should converts seconds in hours, minutes and seconds. 
# Here write your answer
seconds= int(input("Enter time in seconds: "))
import time
print(time.strftime("%H hours, %M minutes, %S seconds", time.gmtime(seconds)))
## Question 08

Write a program which accept principle, rate and time from user and print the simple interest. The formula to calculate simple interest is: 

$$\mathbf{ \text{Simple Interest} = \frac{\text{Principal} \times \text{Rate} \times \text{Time}}{100}}$$

# Here write your answer
principal= int(input("Enter Principal amount: "))
rate= int(input("Enter Rate of Interest: "))
timee= int(input("Enter Time: "))
simp_interest= (principal*rate*timee)/100

print(f"Interest is {simp_interest}")
## Question 09. Distance Traveled 
Write a program to calculate the distance traveled by a car , assuming there are no accidents or delays, the distance that a car travels down the inter-state can be calculated with the following formula:

$$Distance = Speed * Time$$

A car is traveling at 60 miles per hour. Write a program that displays the following:  
• The distance the car will travel in 5 hours        
• The distance the car will travel in 8 hours     
• The distance the car will travel in 12 hours    
# Here write your answer
speed=60
time1=5
time2=8
time3=12

Distance1= speed*time1
Distance2= speed*time2
Distance3= speed*time3
print(f"The car will travel {Distance1} miles in {time1} hours")
print(f"The car will travel {Distance2} miles in {time2} hours")
print(f"The car will travel {Distance3} miles in {time3} hours")
## 10. Stock Transaction Program
Last month Joe purchased some stock in Acme Software, Inc. Here are the details of the
purchase:
* The number of shares that Joe purchased was 1,000.    
* When Joe purchased the stock, he paid $32.87 per share.   
* Joe paid his stockbroker a commission that amounted to 2 percent of the amount he paid
for the stock.   

Two weeks later Joe sold the stock. Here are the details of the sale: 
* The number of shares that Joe sold was 1,000.
* He sold the stock for $33.92 per share.
* He paid his stockbroker another commission that amounted to 2 percent of the amount
  he received for the stock.

Write a program that displays the following information:
* The amount of money Joe paid for the stock.
* The amount of commission Joe paid his broker when he bought the stock.
* The amount that Joe sold the stock for.
* The amount of commission Joe paid his broker when he sold the stock.
* Display the amount of money that Joe had left when he sold the stock and paid his
  broker (both times). If this amount is positive, then Joe made a profit. If the amount is negative, then Joe lost money
# Here write your answer
shares_purchased= 1000
price_perShare= 32.87
total_stock_price=shares_purchased*price_perShare
broker_commission= (2/100)*total_stock_price
amount_paid=total_stock_price+broker_commission
shares_sold=1000
selling_price_perShare=33.92
total_selling_price=shares_sold*selling_price_perShare
received_profit=total_selling_price-total_stock_price
selling_broker_commission= (2/100)*total_selling_price
amount_received=total_selling_price-selling_broker_commission
amount_inHand=amount_received-amount_paid
if amount_inHand>0:
    print(f"Net Profit is ${amount_inHand}")
else:
    print(f"Net Loss from stocks trading  is ${amount_inHand}")
print(f"Amount paid for stocks ${amount_paid}")
print(f"Amount of commission paid to broker ${broker_commission}")
print(f"Amount received after selling of stocks ${total_selling_price}")
print(f"Amount of commission paid to broker on sold stocks ${selling_broker_commission}")
